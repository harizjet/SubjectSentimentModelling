# %% [markdown]
# <h1>--- Done ---</h1>

# %%
import pandas as pd
import os

# %% [markdown]
# - ### View data

# %%
df = pd.read_csv("../data/twitter_data.csv")
df.shape
# Out:
# D:\Dropbox\Academics\Master (Msc)\MSC AI\Sem 2\Machine Learning\Assignment\Mini Project\SubjectSentimentModelling\env\lib\site-packages\IPython\core\interactiveshell.py:3398: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (45549, 36)

# %%
df.head()
# Out:
#                     id      conversation_id  \
# 0  1548324974062055425  1548324974062055425
# 1  1548324934325133313  1548320272813395971
# 2  1548324912061825024  1548006028570009602
# 3  1548324808466714627  1548006028570009602
# 4  1548324303053107202  1548028742387130368
#
#                                           created_at        date      time  \
# 0  2022-07-16 23:13:34 Malay Peninsula Standard Time  2022-07-16  23:13:34
# 1  2022-07-16 23:13:25 Malay Peninsula Standard Time  2022-07-16  23:13:25
# 2  2022-07-16 23:13:20 Malay Peninsula Standard Time  2022-07-16  23:13:20
# 3  2022-07-16 23:12:55 Malay Peninsula Standard Time  2022-07-16  23:12:55
# 4  2022-07-16 23:10:54 Malay Peninsula Standard Time  2022-07-16  23:10:54
#
#    timezone              user_id         username  \
# 0       800   913885380725891072      lukechudoba
# 1       800           3087806261      0xmamba_eth
# 2       800  1087031566654676997  kickboxincorpse
# 3       800  1087031566654676997  kickboxincorpse
# 4       800   829762358172086273      insomniass_
#
#                             name place  ... geo source user_rt_id user_rt  \
# 0                   Luke Chudoba   NaN  ... NaN    NaN        NaN     NaN
# 1                    0xmamba.eth   NaN  ... NaN    NaN        NaN     NaN
# 2           Fuck Pineapple Pizza   NaN  ... NaN    NaN        NaN     NaN
# 3           Fuck Pineapple Pizza   NaN  ... NaN    NaN        NaN     NaN
# 4  🇺🇦♏︎•.𝕧𝕚𝕝𝕝𝕖𝕞 𝕡𝕠𝕨𝕖𝕣𝕫𝕖𝕟𝕜𝕠.•♏︎🇵🇸   NaN  ... NaN    NaN        NaN     NaN
#
#   retweet_id                                           reply_to  retweet_date  \
# 0        NaN                                                 []           NaN
# 1        NaN  [{'screen_name': 'NFTLlama', 'name': 'NFTLlama...           NaN
# 2        NaN  [{'screen_name': 'Benjjjyy', 'name': 'Benj', '...           NaN
# 3        NaN  [{'screen_name': 'Benjjjyy', 'name': 'Benj', '...           NaN
# 4        NaN  [{'screen_name': 'StacyCaySlays', 'name': 'St ...           NaN
#
#    translate trans_src trans_dest
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# - ### Select relevant attributes

# %%
df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
df[['tweet', 'language', 'translate']]
# Out:
#                                                    tweet language  translate
# 0      anong masarap sa pizza yung may pineapple o wala?       tl        NaN
# 1      @coir_twt pineapple pizza is amazing. Thanks f...       en        NaN
# 2                    @neojayz pineapples on pizza is bad       en        NaN
# 3      the only good take mike had this season was pi...       en        NaN
# 4      Leave pineapple on pizza,have you tried pineap...       en        NaN
# ...                                                  ...      ...        ...
# 27692     Pineapple on pizza or  https://t.co/Iy9HZnmSIO       en        NaN
# 27693  just ordered dominos. you guys want any of my ...       en        NaN
# 27694  @Trisha__rc @xiuyouya I would like to apologiz...       en        NaN
# 27695  @Mitch_not_Bill @NewSounddbeats @DSPC_nft @jar...       en        NaN
# 27696  @SpaceAddictsNFT Get #rekt… not even a #degen ...       en        NaN
#
# [27697 rows x 3 columns]

# %%
df['translate'].unique()
# Out:
# array([nan])

# %%
df['language'].unique()
# Out:
# array(['tl', 'en', 'nl', 'fi', 'und', 'qme', 'es', 'ja', 'fa', 'sv', 'it',
#        'de', 'et', 'in', 'fr', 'zh', 'tr', 'pt', 'ar', 'cs', 'ro', 'zxx',
#        'no', 'qst', 'qam', 'ht', 'da', 'pl', 'cy', 'ko', 'art', 'lv',
#        'is', 'qht', 'hi'], dtype=object)

# %%
df.groupby(by=['language'])['language'].count().sort_values(ascending=False)
# Out:
# language
# en     26586
# tl       277
# ja       212
# it        91
# sv        80
# und       69
# qme       58
# et        54
# de        40
# es        38
# fa        35
# in        32
# pt        20
# fr        17
# zxx       12
# nl        11
# ko         7
# qam        7
# tr         6
# fi         6
# ar         5
# zh         5
# da         4
# cs         4
# no         3
# pl         3
# ht         3
# qst        3
# is         2
# ro         2
# cy         1
# hi         1
# lv         1
# art        1
# qht        1
# Name: language, dtype: int64

# %%
df_en = df[df['language'] == 'en'][['tweet']]
print(df_en.shape)
df_en.head()
# Out:
# (26586, 1)
#                                                tweet
# 1  @coir_twt pineapple pizza is amazing. Thanks f...
# 2                @neojayz pineapples on pizza is bad
# 3  the only good take mike had this season was pi...
# 4  Leave pineapple on pizza,have you tried pineap...
# 5                     Pineapple on account of Pizza.

# %%
df_explore_en = df_en.copy()

# %% [markdown]
# - ### Select relevant tweet

# %%
import re

# %%
df_explore_en.shape
# Out:
# (26586, 1)

# %%
# tweet with pizza & pineapple

df_explore_en[df_explore_en['tweet'].apply(lambda x: True if re.search(r'pineapple[s]?.*pizza[s]?|pizza[s]?.*pineapple[s]?', x.lower()) else False)]
# Out:
#                                                    tweet
# 1      @coir_twt pineapple pizza is amazing. Thanks f...
# 2                    @neojayz pineapples on pizza is bad
# 3      the only good take mike had this season was pi...
# 4      Leave pineapple on pizza,have you tried pineap...
# 5                         Pineapple on account of Pizza.
# ...                                                  ...
# 27691  @0xd51 @NFTBurn32 @safemoon_solid He’s shootin...
# 27692     Pineapple on pizza or  https://t.co/Iy9HZnmSIO
# 27693  just ordered dominos. you guys want any of my ...
# 27695  @Mitch_not_Bill @NewSounddbeats @DSPC_nft @jar...
# 27696  @SpaceAddictsNFT Get #rekt… not even a #degen ...
#
# [24972 rows x 1 columns]

# %%
# tweet with no pizza or pineapple

df_temp = df_explore_en[df_explore_en['tweet'].apply(lambda x: False if re.search(r'pineapple[s]?.*pizza[s]?|pizza[s]?.*pineapple[s]?', x.lower()) else True)]
df_temp
# Out:
#                                                    tweet
# 12     I be looking at the hot sign at Krispy Kreme t...
# 13     @fuslie @Valkyrae Maybe Rae can get her reveng...
# 40     @kebdyd @itsraechill True but I meant for call...
# 56              @InfiDale3476 @JamesWe23103648 the patsy
# 64     @lynchk8e @freshwaterpurl @JaneotN Little bit ...
# ...                                                  ...
# 27645                        @nikxleaf Congratulations!!
# 27648          @karaavaldez Good night, sweet dreams!! ♡
# 27661  @eruhimeGA Stay safe and take care of yourself...
# 27664  @keq1ng_ Hii, I am sorry for your loss :( rip!...
# 27694  @Trisha__rc @xiuyouya I would like to apologiz...
#
# [1614 rows x 1 columns]

# %%
df_temp.iloc[0]['tweet']
# Out:
# 'I be looking at the hot sign at Krispy Kreme the same way Will be looking at Mike 🤣 #StrangerThings'

# %%
df_temp.iloc[5]['tweet']
# Out:
# '@wahl_kathaleen @freshwaterpurl I think the correct term here is *rape*, because someone having sex with an 10/11 year old is breaking the law. No sane person would doubt that-an 10 or 11 year old is coercible. The sex of said 10/11 year old is irrelevant. Break that habit'

# %% [markdown]
# - ### data exploration

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hariz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# show wordcloud for the text

from wordcloud import WordCloud
import matplotlib.pyplot as plt

words = ''
for i, tdf in df_explore_en.iterrows():
    words += ' ' + tdf['tweet'].lower()

wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(words)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
# show the word count dict

from collections import defaultdict

word_counter = defaultdict(lambda: 0)
for i, tdf in df_explore_en.iterrows():
    tokenize_word = word_tokenize(tdf['tweet'])
    for w in tokenize_word:
        word_counter[w] += 1
{k: v for k, v in sorted(word_counter.items(), key=lambda x: x[1], reverse=True)}
# Out:
# {'@': 24042,
#  'pizza': 23501,
#  'on': 18234,
#  'pineapple': 17536,
#  '.': 15600,
#  ',': 9978,
#  'I': 9477,
#  'the': 7758,
#  'is': 6982,
#  'a': 6974,
#  '!': 6373,
#  'and': 6229,
#  'Pineapple': 6022,
#  'to': 5470,
#  'it': 5335,
#  '’': 4726,
#  '?': 4702,
#  'you': 4209,
#  'DNPthree': 4140,
#  ':': 4041,
#  'like': 3627,
#  'of': 3510,
#  'with': 3501,
#  'that': 3170,
#  'not': 2881,
#  'in': 2819,
#  'https': 2682,
#  '#': 2646,
#  'for': 2589,
#  'but': 2574,
#  'my': 2424,
#  'Pizza': 2297,
#  "n't": 2226,
#  "'s": 2003,
#  'i': 1992,
#  'do': 1874,
#  'belongs': 1733,
#  't': 1732,
#  'be': 1666,
#  'me': 1655,
#  'have': 1593,
#  's': 1542,
#  'belong': 1496,
#  'good': 1482,
#  'so': 1464,
#  'this': 1432,
#  'are': 1421,
#  'or': 1401,
#  'pineapples': 1371,
#  'does': 1322,
#  ';': 1318,
#  'just': 1271,
#  'love': 1263,
#  'if': 1233,
#  'was': 1198,
#  '&': 1194,
#  'can': 1154,
#  'about': 1132,
#  'no': 1116,
#  'PIZZA': 1051,
#  ')': 1038,
#  'your': 1021,
#  'people': 1008,
#  'as': 1003,
#  'all': 985,
#  '...': 951,
#  'PINEAPPLE': 946,
#  '(': 932,
#  'eat': 901,
#  'It': 877,
#  'who': 849,
#  'they': 825,
#  'we': 815,
#  'put': 810,
#  'The': 785,
#  'ON': 769,
#  'go': 768,
#  'he': 768,
#  'will': 750,
#  'one': 739,
#  "''": 727,
#  'think': 724,
#  'what': 723,
#  'You': 721,
#  '``': 720,
#  '-': 715,
#  'at': 704,
#  'don': 685,
#  '🍕': 660,
#  'an': 657,
#  'from': 651,
#  'only': 644,
#  'would': 644,
#  "'m": 625,
#  'when': 613,
#  'likes': 612,
#  'No': 611,
#  'get': 604,
#  'some': 599,
#  'StrangerThings': 585,
#  'ham': 584,
#  'gt': 580,
#  'm': 573,
#  'has': 568,
#  'Yes': 556,
#  'know': 550,
#  'there': 543,
#  'should': 535,
#  'had': 528,
#  'out': 526,
#  'say': 521,
#  'really': 515,
#  'hate': 496,
#  'If': 491,
#  'never': 485,
#  'right': 484,
#  '*': 480,
#  'things': 479,
#  'make': 476,
#  'up': 474,
#  'amp': 471,
#  '“': 467,
#  'too': 462,
#  '..': 456,
#  'mike': 453,
#  '”': 451,
#  'their': 450,
#  'because': 444,
#  'now': 441,
#  'want': 439,
#  'she': 436,
#  'And': 434,
#  'even': 421,
#  'But': 421,
#  'best': 420,
#  'yes': 420,
#  'then': 418,
#  'cheese': 413,
#  'time': 410,
#  'how': 403,
#  'thing': 401,
#  'why': 400,
#  'than': 397,
#  'also': 395,
#  'more': 395,
#  '🍍': 394,
#  'by': 387,
#  'Hawaiian': 381,
#  'try': 380,
#  'A': 375,
#  'her': 369,
#  'This': 367,
#  'taste': 359,
#  'sauce': 355,
#  'them': 354,
#  'bad': 347,
#  'said': 345,
#  'el': 344,
#  'way': 343,
#  'got': 339,
#  'topping': 338,
#  'bacon': 335,
#  'his': 334,
#  'still': 330,
#  'tried': 329,
#  'doesn': 329,
#  'u': 327,
#  'na': 326,
#  'That': 325,
#  '😂': 325,
#  'did': 324,
#  'pepperoni': 321,
#  'StrangerThings4': 319,
#  'Not': 316,
#  'IS': 313,
#  'We': 313,
#  'better': 313,
#  'Pineapples': 312,
#  'other': 312,
#  'being': 307,
#  'What': 306,
#  "'re": 294,
#  'actually': 293,
#  'am': 292,
#  'here': 290,
#  'lol': 287,
#  'Do': 287,
#  'much': 284,
#  'delicious': 284,
#  'goes': 283,
#  'its': 281,
#  'agree': 280,
#  'wrong': 279,
#  'over': 278,
#  'liking': 278,
#  'opinion': 272,
#  'someone': 270,
#  'My': 270,
#  'order': 269,
#  'well': 269,
#  'need': 268,
#  'eating': 268,
#  'chicken': 268,
#  'everyone': 264,
#  'take': 255,
#  'great': 255,
#  'him': 254,
#  'going': 254,
#  'sweet': 253,
#  "'ve": 250,
#  'could': 250,
#  're': 248,
#  'always': 247,
#  'ever': 245,
#  'So': 241,
#  'real': 240,
#  'see': 240,
#  'any': 240,
#  'made': 237,
#  'day': 237,
#  'debate': 235,
#  'been': 231,
#  'Just': 229,
#  'fruit': 229,
#  'same': 228,
#  'NOT': 228,
#  'without': 228,
#  'something': 227,
#  'food': 226,
#  'though': 226,
#  'most': 224,
#  'favorite': 223,
#  '10': 222,
#  'gon': 222,
#  'off': 221,
#  'He': 220,
#  'Stranger': 218,
#  'putting': 214,
#  'before': 213,
#  'our': 213,
#  '2': 213,
#  'definitely': 210,
#  'very': 210,
#  'Mike': 207,
#  'dont': 205,
#  "'ll": 203,
#  'Does': 203,
#  'life': 202,
#  'eleven': 202,
#  'enjoy': 201,
#  'ca': 200,
#  'El': 198,
#  'THE': 197,
#  '🤣': 196,
#  'There': 195,
#  'those': 193,
#  'first': 192,
#  'Things': 192,
#  'toppings': 190,
#  've': 187,
#  'fucking': 186,
#  'feel': 186,
#  'sure': 186,
#  'anyone': 185,
#  'EL': 183,
#  'Italian': 182,
#  'where': 181,
#  'whether': 180,
#  'into': 180,
#  'stranger': 179,
#  '$': 179,
#  'amazing': 178,
#  'us': 177,
#  'They': 176,
#  'having': 175,
#  'Eleven': 175,
#  'person': 174,
#  'makes': 174,
#  'fine': 174,
#  'after': 173,
#  'Canadian': 170,
#  'll': 170,
#  'rights': 170,
#  'which': 169,
#  '😋': 168,
#  '....': 167,
#  'anything': 166,
#  'together': 166,
#  'saying': 166,
#  'own': 166,
#  'shit': 164,
#  'mind': 164,
#  'were': 163,
#  "'": 162,
#  'back': 161,
#  'let': 161,
#  'story': 161,
#  'She': 161,
#  'topped': 160,
#  "'d": 160,
#  'tell': 159,
#  'world': 158,
#  'true': 158,
#  '1': 158,
#  'anchovies': 157,
#  'new': 157,
#  'olives': 157,
#  'disagree': 156,
#  'against': 156,
#  'YOU': 155,
#  'fan': 155,
#  'friends': 154,
#  'Why': 154,
#  'believe': 154,
#  'im': 153,
#  'thought': 152,
#  'must': 151,
#  'Oh': 150,
#  'hot': 149,
#  'place': 149,
#  'Ericjoojoo': 148,
#  'absolutely': 147,
#  'People': 147,
#  'jalapeño': 146,
#  'question': 146,
#  'okay': 145,
#  '3': 145,
#  'fact': 144,
#  'weird': 144,
#  'man': 143,
#  'lt': 143,
#  'whole': 142,
#  'course': 142,
#  'Also': 141,
#  'tho': 140,
#  '%': 140,
#  'Is': 140,
#  'both': 139,
#  'mean': 139,
#  'different': 139,
#  'As': 138,
#  'give': 137,
#  'nice': 137,
#  'guy': 137,
#  'big': 137,
#  'probably': 137,
#  'crime': 137,
#  'NO': 136,
#  'trying': 136,
#  'come': 135,
#  'add': 135,
#  'once': 134,
#  'long': 134,
#  '4': 133,
#  'AND': 132,
#  'top': 132,
#  'little': 132,
#  '+': 132,
#  'DOES': 132,
#  'last': 132,
#  'down': 130,
#  'understand': 130,
#  'today': 130,
#  '😭': 129,
#  'human': 129,
#  'BitcoinPunkNFT': 128,
#  'hates': 126,
#  'Stranger_Things': 126,
#  'please': 126,
#  'Argyle': 125,
#  'tastes': 124,
#  'pretty': 124,
#  'talk': 123,
#  'pizzas': 122,
#  'many': 122,
#  'everything': 122,
#  'looks': 122,
#  'guys': 121,
#  'ate': 121,
#  'IT': 120,
#  'while': 119,
#  'ok': 119,
#  'kind': 119,
#  'talking': 118,
#  'crust': 118,
#  'since': 118,
#  'When': 118,
#  'these': 117,
#  'prefer': 117,
#  'guess': 117,
#  'cream': 117,
#  'In': 116,
#  'might': 116,
#  'used': 115,
#  'pizza…': 115,
#  'getting': 115,
#  'opinions': 115,
#  'disgusting': 114,
#  'else': 113,
#  '•': 113,
#  'again': 113,
#  'YES': 113,
#  'peppers': 112,
#  'either': 112,
#  'argyle': 112,
#  'hope': 110,
#  'How': 110,
#  'away': 110,
#  'SO': 110,
#  'night': 110,
#  'maybe': 110,
#  'HatoETH': 110,
#  'loves': 109,
#  'care': 109,
#  'every': 109,
#  'jalapeños': 108,
#  'For': 108,
#  'another': 108,
#  'Or': 107,
#  'pie': 107,
#  'ordered': 106,
#  'next': 106,
#  'ask': 105,
#  'may': 105,
#  'GOOD': 104,
#  'hawaiian': 104,
#  'literally': 104,
#  'salty': 104,
#  'tomato': 104,
#  'years': 103,
#  'liked': 103,
#  'reason': 103,
#  'says': 103,
#  'season': 102,
#  'hyxpk': 102,
#  'least': 102,
#  'meat': 102,
#  'sorry': 102,
#  'ChefGruel': 101,
#  'fuck': 101,
#  'hell': 101,
#  'dominos': 100,
#  'call': 100,
#  'red': 99,
#  '//': 99,
#  'Well': 98,
#  'enough': 98,
#  'instead': 98,
#  'Love': 98,
#  'd': 98,
#  'Thank': 97,
#  'banana': 97,
#  'until': 97,
#  'nothing': 96,
#  'lot': 96,
#  'Ham': 96,
#  'work': 96,
#  'especially': 96,
#  'black': 96,
#  'LIKE': 96,
#  'PINEAPPLES': 95,
#  'cause': 95,
#  'stop': 94,
#  '🍍🍕': 94,
#  'myself': 94,
#  'doing': 93,
#  'die': 93,
#  'mushrooms': 93,
#  'green': 92,
#  '_Silvervale_': 92,
#  'Yeah': 91,
#  'Lol': 91,
#  'use': 91,
#  'lover': 91,
#  'controversial': 90,
#  'making': 90,
#  'gross': 90,
#  'slice': 90,
#  'ice': 90,
#  'BBQ': 90,
#  'LIKES': 89,
#  'Can': 89,
#  'scene': 89,
#  'juice': 89,
#  'part': 89,
#  'hating': 89,
#  'fun': 89,
#  'On': 89,
#  'yeah': 88,
#  'free': 88,
#  'heard': 88,
#  'personally': 88,
#  'worst': 88,
#  'combo': 88,
#  'start': 88,
#  'two': 87,
#  'perfect': 87,
#  '😅': 87,
#  'ppl': 86,
#  'kinda': 86,
#  'spoilers': 86,
#  '🤔': 86,
#  'sometimes': 85,
#  'puts': 85,
#  'side': 84,
#  'needs': 84,
#  'LOVE': 84,
#  'ass': 83,
#  'already': 83,
#  'Your': 83,
#  'Now': 83,
#  'worse': 83,
#  'yay': 82,
#  '🤤': 82,
#  'All': 82,
#  'hear': 82,
#  'find': 82,
#  'Of': 82,
#  'bc': 81,
#  'ur': 81,
#  'ta': 81,
#  'except': 81,
#  'Let': 81,
#  'far': 81,
#  'Maybe': 80,
#  'ELEVEN': 80,
#  'show': 80,
#  'TO': 80,
#  'Don': 80,
#  'chocolate': 80,
#  'comes': 80,
#  'To': 80,
#  '😁': 80,
#  'nay': 79,
#  'bit': 79,
#  'y': 79,
#  'extra': 78,
#  'point': 78,
#  'DO': 78,
#  'look': 78,
#  'lovers': 78,
#  'mint': 78,
#  'hard': 78,
#  'MIKE': 78,
#  'anti': 78,
#  'Like': 77,
#  'eats': 77,
#  'choice': 77,
#  'fresh': 76,
#  'keep': 76,
#  '100': 76,
#  'ya': 76,
#  'isn': 76,
#  'wan': 75,
#  'problem': 75,
#  'stand': 75,
#  'knew': 75,
#  'happy': 75,
#  'Me': 75,
#  'thinks': 75,
#  '5': 75,
#  'deny': 74,
#  'InfiDale3476': 74,
#  'didn': 74,
#  'others': 74,
#  'oh': 74,
#  'matter': 74,
#  'each': 74,
#  'Supreme': 74,
#  'sausage': 73,
#  'trust': 73,
#  'such': 73,
#  'girl': 73,
#  'end': 73,
#  'otherwise': 73,
#  'around': 73,
#  'coming': 72,
#  'fight': 72,
#  '🤢': 72,
#  'Pepperoni': 72,
#  'D': 72,
#  'stuff': 71,
#  'idea': 71,
#  'flavor': 71,
#  'hater': 71,
#  '‘': 71,
#  'god': 70,
#  'half': 70,
#  'change': 70,
#  'times': 70,
#  'Nah': 69,
#  'stay': 69,
#  'kids': 69,
#  'dinner': 69,
#  'done': 69,
#  'live': 69,
#  'w': 68,
#  'savory': 68,
#  'answer': 67,
#  'Never': 67,
#  'ketchup': 67,
#  'Some': 67,
#  'called': 66,
#  'old': 66,
#  'tweet': 66,
#  'pepper': 66,
#  'StrangerThings4Vol2': 66,
#  'Chicken': 66,
#  'force': 66,
#  '👀': 66,
#  'told': 65,
#  'damn': 65,
#  '😍': 65,
#  'spicy': 65,
#  'Only': 65,
#  'wo': 65,
#  'Try': 64,
#  'whatever': 64,
#  'came': 64,
#  'yet': 64,
#  'Even': 64,
#  'MY': 64,
#  'thinking': 64,
#  'sweetness': 64,
#  'garlic': 64,
#  'depends': 64,
#  'lucasj8': 64,
#  'Who': 63,
#  'week': 63,
#  'Hawaii': 63,
#  '🤮': 63,
#  'thank': 63,
#  'Wario64': 63,
#  'cooked': 62,
#  '…': 62,
#  'gets': 62,
#  'onions': 62,
#  'abomination': 62,
#  'dislike': 62,
#  'tasty': 62,
#  'BELONGS': 62,
#  'bbq': 62,
#  'near': 62,
#  'sin': 61,
#  'few': 61,
#  'haha': 61,
#  'idk': 61,
#  'difference': 61,
#  'win': 61,
#  'team': 61,
#  'BELONG': 61,
#  'funny': 61,
#  'invented': 61,
#  'cute': 60,
#  'white': 60,
#  'line': 60,
#  'yummy': 60,
#  '=': 60,
#  'honestly': 60,
#  'important': 59,
#  '[': 59,
#  ']': 59,
#  'doesnt': 59,
#  'almost': 59,
#  'Court': 59,
#  'combination': 58,
#  'help': 58,
#  'U': 58,
#  'Canada': 58,
#  'won': 58,
#  'rather': 58,
#  'year': 57,
#  'watching': 57,
#  'character': 57,
#  '—': 57,
#  '⠀': 57,
#  'enjoyer': 57,
#  'lost': 57,
#  'type': 57,
#  'itself': 57,
#  'Have': 57,
#  'mine': 57,
#  'Italy': 57,
#  'issue': 57,
#  'klaus': 57,
#  '🔥': 56,
#  'knows': 56,
#  'saw': 56,
#  'wait': 56,
#  'sounds': 56,
#  'remember': 56,
#  'Absolutely': 56,
#  'Good': 56,
#  'means': 55,
#  'deserve': 55,
#  'argument': 55,
#  'finally': 55,
#  'asked': 55,
#  'normal': 55,
#  'argue': 55,
#  'God': 55,
#  'favourite': 55,
#  'chance': 55,
#  'buy': 55,
#  'ones': 54,
#  'wanted': 54,
#  'seen': 54,
#  'cake': 54,
#  'rules': 54,
#  'fire': 54,
#  'sense': 54,
#  'WHAT': 54,
#  'n': 54,
#  'NinaKosaka': 54,
#  'Klaus': 53,
#  'One': 53,
#  'tbh': 53,
#  'bro': 53,
#  'respect': 53,
#  'awesome': 53,
#  'choose': 53,
#  'At': 53,
#  'Italians': 53,
#  'boy': 53,
#  'Thanks': 52,
#  'lmao': 52,
#  'high': 52,
#  'onion': 52,
#  'between': 52,
#  'wheeler': 52,
#  'war': 52,
#  'spoiler': 52,
#  'Whether': 52,
#  'Will': 51,
#  'WITH': 51,
#  'past': 51,
#  'slices': 51,
#  'case': 51,
#  'loved': 51,
#  'Happy': 51,
#  'personal': 51,
#  'crazy': 51,
#  'deserves': 51,
#  '😉': 51,
#  'cuz': 50,
#  'watch': 50,
#  'style': 50,
#  'Eve6': 50,
#  'tomatoes': 50,
#  'Ok': 50,
#  'friend': 50,
#  '💀': 50,
#  '😊': 50,
#  'less': 50,
#  'found': 50,
#  'allowed': 50,
#  'gives': 50,
#  'women': 49,
#  'left': 49,
#  'Here': 49,
#  'haters': 49,
#  'based': 49,
#  'along': 49,
#  'read': 49,
#  '😭😭': 49,
#  'Hey': 49,
#  'works': 49,
#  'started': 48,
#  'house': 48,
#  'CarlGrubb12': 48,
#  'ThomasKemmett': 48,
#  'SpankySpankster': 48,
#  'name': 48,
#  'butter': 48,
#  'cool': 48,
#  'acceptable': 48,
#  'thin': 48,
#  'THAT': 48,
#  'ai': 48,
#  'thoughts': 48,
#  '❤️': 48,
#  'BEST': 47,
#  'dare': 47,
#  'bring': 47,
#  'blasphemy': 47,
#  'Bacon': 47,
#  'rn': 47,
#  '😂😂': 47,
#  'under': 47,
#  'throw': 47,
#  '😂😂😂': 47,
#  'usually': 47,
#  'Did': 47,
#  'Day': 47,
#  'mushroom': 47,
#  'ranch': 47,
#  'illegal': 47,
#  'mix': 46,
#  'Sweet': 46,
#  'Then': 46,
#  'heart': 46,
#  'went': 46,
#  'rest': 46,
#  'twitter': 46,
#  'through': 46,
#  "N'T": 46,
#  'An': 46,
#  'MOthinus': 46,
#  'official_te0': 46,
#  'propaganda': 45,
#  'tonight': 45,
#  'joke': 45,
#  'ARE': 45,
#  'loving': 45,
#  'support': 45,
#  '😆': 45,
#  'craving': 45,
#  'accept': 45,
#  'thanks': 45,
#  'With': 45,
#  'salad': 45,
#  'rice': 44,
#  'biggest': 44,
#  'wouldn': 44,
#  'bet': 44,
#  'Get': 44,
#  'idc': 44,
#  'sucks': 44,
#  'forget': 44,
#  'Twitter': 44,
#  'glad': 44,
#  'tier': 44,
#  'evil': 43,
#  'seeing': 43,
#  'front': 43,
#  'REAL': 43,
#  'Are': 43,
#  'family': 43,
#  '.....': 43,
#  'Olives': 43,
#  'humanity': 43,
#  'abortion': 43,
#  'corn': 43,
#  'New': 43,
#  'burger': 43,
#  'judge': 42,
#  'slaps': 42,
#  'post': 42,
#  '🍕🍍': 42,
#  'pro': 42,
#  'listen': 42,
#  'agenda': 42,
#  'Hot': 42,
#  'shouldn': 42,
#  'Really': 42,
#  'nah': 42,
#  'leave': 42,
#  'CallMeIree': 42,
#  'ordering': 41,
#  'totally': 41,
#  'ago': 41,
#  'questions': 41,
#  'list': 41,
#  'wish': 41,
#  'BUT': 41,
#  "y'all": 41,
#  'HER': 41,
#  'feeling': 41,
#  'game': 41,
#  'HATE': 41,
#  'home': 41,
#  'country': 41,
#  '🧐': 41,
#  'deep': 41,
#  '6lnchst1lettos': 41,
#  'THIS': 40,
#  'via': 40,
#  'Everyone': 40,
#  'wants': 40,
#  'exist': 40,
#  'dude': 40,
#  'baby': 40,
#  'trash': 40,
#  'jalapeno': 40,
#  '😎': 40,
#  'exactly': 40,
#  'save': 40,
#  'small': 40,
#  'ofc': 40,
#  'moment': 40,
#  'pork': 40,
#  'JayExci': 40,
#  'Where': 40,
#  'business': 40,
#  'general': 40,
#  'Nope': 40,
#  'alone': 40,
#  'certain': 40,
#  'MartinSLewis': 40,
#  'adamliaw': 40,
#  'FOR': 39,
#  'during': 39,
#  'truther': 39,
#  'GO': 39,
#  'forever': 39,
#  'Sorry': 39,
#  'Best': 39,
#  'hill': 39,
#  'spinach': 39,
#  'Cheese': 39,
#  'break': 39,
#  'US': 39,
#  'Today': 39,
#  'mad': 39,
#  'WrongsToWrite': 39,
#  'base': 39,
#  'pasta': 39,
#  'RAZ0RFIST': 39,
#  'looking': 38,
#  'wife': 38,
#  'entire': 38,
#  'confirmed': 38,
#  'pickles': 38,
#  'apple': 38,
#  'etc': 38,
#  '🥰': 38,
#  'yall': 38,
#  'MacroAlf': 38,
#  'deal': 38,
#  'takes': 38,
#  'cant': 38,
#  'weekend': 38,
#  'created': 38,
#  'TheCartelDel': 38,
#  'drink': 38,
#  'OF': 37,
#  'perfectly': 37,
#  'tired': 37,
#  'wasn': 37,
#  'including': 37,
#  'Okay': 37,
#  'yourself': 37,
#  'truly': 37,
#  'topic': 37,
#  'SHE': 37,
#  'beef': 37,
#  'woman': 37,
#  'elite': 37,
#  'media': 37,
#  'def': 37,
#  'Go': 37,
#  'ALL': 37,
#  'Y': 37,
#  'Definitely': 37,
#  'learned': 37,
#  'unless': 37,
#  'Tsuki_Anachi': 37,
#  'coir_twt': 36,
#  'fried': 36,
#  '11': 36,
#  'breakfast': 36,
#  'DeconstrucTed80': 36,
#  'days': 36,
#  'taking': 36,
#  'quite': 36,
#  'foods': 36,
#  'superior': 36,
#  'FUCKING': 36,
#  'Would': 36,
#  'OK': 36,
#  'preference': 36,
#  'however': 36,
#  'horrible': 36,
#  'x': 36,
#  '6-3': 36,
#  'political': 36,
#  'eaten': 36,
#  'second': 36,
#  'John': 36,
#  'PatrioticPizzas': 36,
#  'HE': 35,
#  'men': 35,
#  'correct': 35,
#  'Got': 35,
#  'Great': 35,
#  '😌': 35,
#  'send': 35,
#  '🥲': 35,
#  'movie': 35,
#  'sick': 35,
#  'hand': 35,
#  'valid': 35,
#  'special': 35,
#  'haven': 35,
#  'operationSIN': 35,
#  'birthday': 35,
#  'open': 35,
#  'share': 35,
#  'Personally': 35,
#  'Because': 35,
#  ...}

# %%
# show the word count distribution

fig, axe = plt.subplots(figsize=(16, 16), nrows=1, ncols=2)
axe[0].hist([v for k, v in word_counter.items()], bins=10);
axe[1].boxplot([v for k, v in word_counter.items()]);

# %% [markdown]
# - ### vader prediction

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
vaderPredict = SentimentIntensityAnalyzer()

# %% [markdown]
# #### - vader performed very well on noisy data

# %%
vaderPredict.polarity_scores('🤔')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
vaderPredict.polarity_scores('🥰')
# Out:
# {'neg': 0.0, 'neu': 0.291, 'pos': 0.709, 'compound': 0.8074}

# %%
vaderPredict.polarity_scores('#happy')
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5719}

# %%
vaderPredict.polarity_scores('#happygolucky')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
vaderPredict.polarity_scores('yummy')
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5267}

# %%
vaderPredict.polarity_scores('yummy!')
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5707}

# %%
vaderPredict.polarity_scores('yummy!!!')
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6458}

# %%
# we dont think there is a need to do cleaning, because Vader is performing very well on raw data
# it even assign value to some of the emoji & hashtag

# %%
# create basic filtering

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')
stp = set(stopwords.words('english'))
pst = PorterStemmer()

def cleaning_text(txt):
    txt = txt.lower()
    txt = re.sub(r'@\w*', 'USER', txt) # replaced user tagged with another obj
    txt = re.sub(r"(.)\1\1+", r"\1\1", txt) # replaced 3 or more sequences to 2 sequences
    txt = re.sub(r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)", '', txt) # removing url
    txt = re.sub(r'#\w*\s+', '', txt) # removing hashtag
    txt = re.sub(r'[^a-zA-Z0-9]', ' ', txt) # removing symbol and punctuation and other noise
    txt = ' '.join([pst.stem(x) for x in txt.split(' ')]) # stemming
    txt = ' '.join([x for x in txt.split(' ') if x not in stp]) # removing stopwords
    
    return txt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hariz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# for the sake of simplicity and discrepancy, we are only going to compare positive and negative

# %%
# compare the result between cleaning and raw

import seaborn as sns

df_explore_en_clean = df_explore_en.copy()
df_explore_en_clean['tweet'] = df_explore_en_clean['tweet'].apply(lambda x: cleaning_text(x))
df_explore_en_raw = df_explore_en.copy()

df_explore_en_clean['label'] = df_explore_en_clean['tweet'].apply(lambda x: 
            'pos' if vaderPredict.polarity_scores(x)['compound'] >= 0 else 'neg')
df_explore_en_raw['label'] = df_explore_en_raw['tweet'].apply(lambda x: 
            'pos' if vaderPredict.polarity_scores(x)['compound'] >= 0 else 'neg')

print('cleaned data')
print(df_explore_en_clean.groupby(by=['label'])['label'].count())
print('\nraw data')
print(df_explore_en_raw.groupby(by=['label'])['label'].count())

fig, axe = plt.subplots(figsize=(14, 8), nrows=1, ncols=2)

tdf1 = df_explore_en_clean.groupby(by=['label'], as_index=False).count()
tdf1['percent'] = (tdf1['tweet'] / tdf1['tweet'].sum()) * 100
sns.barplot(data=tdf1, x='label', y='percent', ax=axe[0]);
axe[0].set_title('cleaned data')

tdf2 = df_explore_en_raw.groupby(by=['label'], as_index=False).count()
tdf2['percent'] = (tdf2['tweet'] / tdf2['tweet'].sum()) * 100
sns.barplot(data=tdf2, x='label', y='percent', ax=axe[1]);
axe[1].set_title('raw data')

plt.show()
# Out:
# cleaned data
# label
# neg     4361
# pos    22225
# Name: label, dtype: int64
#
# raw data
# label
# neg     5627
# pos    20959
# Name: label, dtype: int64

# %%
# word cloud for both of the label on cleaned data

from wordcloud import WordCloud
import matplotlib.pyplot as plt

stp = set(stopwords.words('english'))

wordspos = ''
for i, tdf in df_explore_en_clean[df_explore_en_clean['label'] == 'pos'].iterrows():
    wordspos += ' ' + tdf['tweet'].lower()

wordcloudpos = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(wordspos)

wordsneg = ''
for i, tdf in df_explore_en_clean[df_explore_en_clean['label'] == 'neg'].iterrows():
    wordsneg += ' ' + tdf['tweet'].lower()

wordcloudneg = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(wordsneg)

fig, axe = plt.subplots(figsize=(16, 8), nrows=1, ncols=2, facecolor = None)

axe[0].imshow(wordcloudpos)
axe[0].axis("off")
axe[0].set_title("cleaned positive")

axe[1].imshow(wordcloudneg)
axe[1].axis("off")
axe[1].set_title("cleaned negative")
 
plt.show()

# %%
# word cloud for both of the label on raw data

from wordcloud import WordCloud
import matplotlib.pyplot as plt

stp = set(stopwords.words('english'))

wordspos = ''
for i, tdf in df_explore_en_clean[df_explore_en_raw['label'] == 'pos'].iterrows():
    wordspos += ' ' + tdf['tweet'].lower()

wordcloudpos = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(wordspos)

wordsneg = ''
for i, tdf in df_explore_en_clean[df_explore_en_raw['label'] == 'neg'].iterrows():
    wordsneg += ' ' + tdf['tweet'].lower()

wordcloudneg = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(wordsneg)

fig, axe = plt.subplots(figsize=(16, 8), nrows=1, ncols=2, facecolor = None)

axe[0].imshow(wordcloudpos)
axe[0].axis("off")
axe[0].set_title("raw positive")

axe[1].imshow(wordcloudneg)
axe[1].axis("off")
axe[1].set_title("raw negative")
 
plt.show()

# %%
# since vader is performed very well on noisy data, we are going to label the raw version
# but for ml, we are going to clean it

# %% [markdown]
# - ### result of data cleaning

# %%
# show the comparison on the top-20 word count between before and after cleaning

from collections import defaultdict

word_counter = defaultdict(lambda: 0)
for i, tdf in df_explore_en_clean.iterrows():
    tokenize_word = word_tokenize(tdf['tweet'])
    for w in tokenize_word:
        word_counter[w] += 1
        
print("cleaned data")
{item[0]: item[1] for i, item in enumerate({k: v for k, v in sorted(word_counter.items(), key=lambda x: x[1], reverse=True)}.items()) if i < 20}
# Out:
# cleaned data
# {'pizza': 27484,
#  'pineappl': 26507,
#  'user': 24036,
#  'like': 4966,
#  'belong': 3413,
#  'thi': 1856,
#  'love': 1725,
#  'good': 1681,
#  'eat': 1306,
#  'doe': 1253,
#  'peopl': 1192,
#  'put': 1189,
#  'wa': 1173,
#  'go': 1122,
#  'thing': 1114,
#  'ye': 1111,
#  'tri': 959,
#  'think': 891,
#  'one': 885,
#  'top': 860}

# %%
word_counter = defaultdict(lambda: 0)
for i, tdf in df_explore_en_raw.iterrows():
    tokenize_word = word_tokenize(tdf['tweet'])
    for w in tokenize_word:
        word_counter[w] += 1
        
print("raw data")
{item[0]: item[1] for i, item in enumerate({k: v for k, v in sorted(word_counter.items(), key=lambda x: x[1], reverse=True)}.items()) if i < 20}
# Out:
# raw data
# {'@': 24042,
#  'pizza': 23501,
#  'on': 18234,
#  'pineapple': 17536,
#  '.': 15600,
#  ',': 9978,
#  'I': 9477,
#  'the': 7758,
#  'is': 6982,
#  'a': 6974,
#  '!': 6373,
#  'and': 6229,
#  'Pineapple': 6022,
#  'to': 5470,
#  'it': 5335,
#  '’': 4726,
#  '?': 4702,
#  'you': 4209,
#  'DNPthree': 4140,
#  ':': 4041}

# %%
# show the comparison for the available vocab

vocab = set()
for i, tdf in df_explore_en_clean.iterrows():
    vocab = vocab.union({x for x in word_tokenize(tdf['tweet'])})
    
print("cleaned data")
len(vocab)
# Out:
# cleaned data
# 9486

# %%
vocab = set()
for i, tdf in df_explore_en_raw.iterrows():
    vocab = vocab.union({x for x in word_tokenize(tdf['tweet'])})
    
print("raw data")
len(vocab)
# Out:
# raw data
# 28083

# %% [markdown]
# - ### do data cleaning on raw for ml

# %%
# create basic filtering

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')
stp = set(stopwords.words('english'))
pst = PorterStemmer()

def cleaning_text(txt):
    txt = txt.lower()
    txt = re.sub(r'@\w*', 'USER', txt) # replaced user tagged with another obj
    txt = re.sub(r"(.)\1\1+", r"\1\1", txt) # replaced 3 or more sequences to 2 sequences
    txt = re.sub(r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)", '', txt) # removing url
    txt = re.sub(r'#\w*\s+', '', txt) # removing hashtag
    txt = re.sub(r'[^a-zA-Z0-9]', ' ', txt) # removing symbol and punctuation and other noise
    txt = ' '.join([pst.stem(x) for x in txt.split(' ')]) # stemming
    txt = ' '.join([x for x in txt.split(' ') if x not in stp]) # removing stopwords
    
    return txt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hariz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataml = df_explore_en_raw.copy()
dataml['cleaned_tweet'] = dataml['tweet'].apply(lambda x: cleaning_text(x))
dataml.tail()
# Out:
#                                                    tweet label  \
# 27692     Pineapple on pizza or  https://t.co/Iy9HZnmSIO   pos
# 27693  just ordered dominos. you guys want any of my ...   pos
# 27694  @Trisha__rc @xiuyouya I would like to apologiz...   neg
# 27695  @Mitch_not_Bill @NewSounddbeats @DSPC_nft @jar...   pos
# 27696  @SpaceAddictsNFT Get #rekt… not even a #degen ...   pos
#
#                                            cleaned_tweet
# 27692                                   pineappl pizza
# 27693          order domino  guy want ani pineappl pizza
# 27694  user user would like apolog  sorri rude behavi...
# 27695  user user user user user think still releas pi...
# 27696  user get  rekt  even eat pineappl  pizza  rede...

# %% [markdown]
# - ### split data

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# %%
X_train, X_test, y_train, y_test = train_test_split(dataml['cleaned_tweet'], dataml['label'], test_size=0.1, random_state=2)
print("train size: {}".format(len(X_train)))
print("test size: {}".format(len(X_test)))
# Out:
# train size: 23927
# test size: 2659

# %%
# save the index & result for comparison purpose in the later section

test_compare = pd.DataFrame()
test_compare['index'] = X_test.index
test_compare['label'] = y_test.values

# %% [markdown]
# - ### get the tfidf to be fit as ml variables

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectoriser = TfidfVectorizer(ngram_range=(1,2))
vectoriser.fit(X_train)
print(f'Vectoriser fitted.')
print('No. of feature_words: ', len(vectoriser.get_feature_names()))
# Out:
# Vectoriser fitted.
# No. of feature_words:  67177
# D:\Dropbox\Project\LegitProject\ProductSentimentModelling\env\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
X_train_tf = vectoriser.transform(X_train)
X_test_tf = vectoriser.transform(X_test)

# %% [markdown]
# - ### create ml model & evaluate

# %%
# create util function for easy model evaluation

def model_Evaluate(model):
    
    # Predict values for Test dataset
    y_pred = model.predict(X_test_tf)

    # Print the evaluation metrics for the dataset.
    print(classification_report(y_test, y_pred))
    
    # Compute and plot the Confusion matrix
    cf_matrix = confusion_matrix(y_test, y_pred)

    categories  = ['Negative','Positive']
    group_names = ['True Neg','False Pos', 'False Neg','True Pos']
    group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten() / np.sum(cf_matrix)]

    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cf_matrix, annot = labels, cmap = 'Blues',fmt = '',
                xticklabels = categories, yticklabels = categories)

    plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
    plt.ylabel("Actual values"   , fontdict = {'size':14}, labelpad = 10)
    plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# %%
# test out naive bayes model

BNBmodel = BernoulliNB(alpha = 2)
BNBmodel.fit(X_train_tf, y_train)
model_Evaluate(BNBmodel)
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.71      0.13      0.22       556
#          pos       0.81      0.99      0.89      2103
#
#     accuracy                           0.81      2659
#    macro avg       0.76      0.56      0.55      2659
# weighted avg       0.79      0.81      0.75      2659

# %%
from sklearn.linear_model import LogisticRegression

# %%
# test out logistic regression model

LRmodel = LogisticRegression(C = 2, max_iter = 1000, n_jobs=-1)
LRmodel.fit(X_train_tf, y_train)
model_Evaluate(LRmodel)
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.91      0.53      0.67       556
#          pos       0.89      0.99      0.93      2103
#
#     accuracy                           0.89      2659
#    macro avg       0.90      0.76      0.80      2659
# weighted avg       0.89      0.89      0.88      2659

# %%
from sklearn.neural_network import MLPClassifier

# %%
# test out perceptron model

clf = MLPClassifier(solver='lbfgs', alpha=0.00005, hidden_layer_sizes=(5, 3), random_state=1)
clf.fit(X_train_tf, y_train)
model_Evaluate(clf)
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.89      0.85      0.87       556
#          pos       0.96      0.97      0.97      2103
#
#     accuracy                           0.95      2659
#    macro avg       0.92      0.91      0.92      2659
# weighted avg       0.94      0.95      0.94      2659
# D:\Dropbox\Project\LegitProject\ProductSentimentModelling\env\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
# we are going to take the perceptron model for comparison

# %% [markdown]
# - ### compare result with vader

# %%
# save the result

test_compare['predict'] = clf.predict(X_test_tf)
test_compare
# Out:
#       index label predict
# 0     21546   pos     pos
# 1      3161   pos     pos
# 2      7819   pos     pos
# 3      6108   neg     neg
# 4     18918   pos     pos
# ...     ...   ...     ...
# 2654  13643   pos     pos
# 2655  21590   pos     pos
# 2656   1644   pos     pos
# 2657   5585   pos     pos
# 2658  19554   pos     pos
#
# [2659 rows x 3 columns]

# %%
# un-matched index

test_compare[test_compare['label'] != test_compare['predict']]
# Out:
#       index label predict
# 14    23217   pos     neg
# 45    17429   neg     pos
# 55    26424   neg     pos
# 67    14477   pos     neg
# 74    11612   neg     pos
# ...     ...   ...     ...
# 2564  24306   pos     neg
# 2567  26355   neg     pos
# 2625  11065   pos     neg
# 2628  24993   neg     pos
# 2638   9147   neg     pos
#
# [146 rows x 3 columns]

# %%
# false positive index

test_compare[(test_compare['label'] == 'neg') & (test_compare['predict'] == 'pos')]
# Out:
#       index label predict
# 45    17429   neg     pos
# 55    26424   neg     pos
# 74    11612   neg     pos
# 99     8348   neg     pos
# 134   10195   neg     pos
# ...     ...   ...     ...
# 2547  22836   neg     pos
# 2563   4044   neg     pos
# 2567  26355   neg     pos
# 2628  24993   neg     pos
# 2638   9147   neg     pos
#
# [86 rows x 3 columns]

# %%
# false negative index

test_compare[(test_compare['label'] == 'pos') & (test_compare['predict'] == 'neg')]
# Out:
#       index label predict
# 14    23217   pos     neg
# 67    14477   pos     neg
# 82    23916   pos     neg
# 87    24346   pos     neg
# 118    3934   pos     neg
# 167   22403   pos     neg
# 373   25388   pos     neg
# 427   12079   pos     neg
# 505   26070   pos     neg
# 516   21968   pos     neg
# 532   25001   pos     neg
# 539   25191   pos     neg
# 545   25944   pos     neg
# 550   16720   pos     neg
# 589    4344   pos     neg
# 664   23361   pos     neg
# 699   23831   pos     neg
# 799   15007   pos     neg
# 1058  23282   pos     neg
# 1103  25289   pos     neg
# 1147   2159   pos     neg
# 1172  23915   pos     neg
# 1177  15330   pos     neg
# 1226  21790   pos     neg
# 1327  24713   pos     neg
# 1342   2215   pos     neg
# 1412  23738   pos     neg
# 1414  24585   pos     neg
# 1435  18492   pos     neg
# 1471   4146   pos     neg
# 1573  24802   pos     neg
# 1574  25192   pos     neg
# 1575  26144   pos     neg
# 1620  22268   pos     neg
# 1621  24666   pos     neg
# 1636  18158   pos     neg
# 1642   7921   pos     neg
# 1673  25272   pos     neg
# 1684    239   pos     neg
# 1690   5656   pos     neg
# 1713  23609   pos     neg
# 1805  26192   pos     neg
# 1913  26448   pos     neg
# 1915  23396   pos     neg
# 2036  17830   pos     neg
# 2039  16014   pos     neg
# 2078  23640   pos     neg
# 2090  25990   pos     neg
# 2178  26362   pos     neg
# 2199  24640   pos     neg
# 2210   1190   pos     neg
# 2300  25061   pos     neg
# 2366  26181   pos     neg
# 2377  26040   pos     neg
# 2428  24493   pos     neg
# 2435  22294   pos     neg
# 2456  24328   pos     neg
# 2550  27512   pos     neg
# 2564  24306   pos     neg
# 2625  11065   pos     neg

# %%
# three sample for false positive

print(df_explore_en_raw.loc[22836, :].tweet)
print(df_explore_en_raw.loc[4044, :].tweet)
print(df_explore_en_raw.loc[26424, :].tweet)
# Out:
# @MOthinus Er...isnt pineapple pizza Hawaiian pizza? To me I prefer Hawaiian without sweet pineapple 😎
# not el liking pineapple on pizza
# @feeblephrog we'll make pineapple pizza there 😭

# %%
# three sample for false negative

print(df_explore_en_raw.loc[12079, :].tweet)
print(df_explore_en_raw.loc[25191, :].tweet)
print(df_explore_en_raw.loc[24585, :].tweet)
# Out:
# @DNPthree Of course put Pineapple on Pizza! I MISS U &amp; Wolfpack!  @DNPthree I hope all of the projects are doing well &amp; coming along! I hope the fam is great! I feel bad I can't be a part of the Gridcraft minting, staking etc but that's ok i'm holdin on to my 2 goobers forever!
# @SparkyMarky1865 Nothing  wrang whi pineapple on a pizza
# @michael79123592 You can never go wrong with pizza unless you ask for pineapple topping.  Just sayin....😇

# %% [markdown]
# ##### therefore, there is not enough evidence of how vader is better than ml approach or vice versa. a more planned practice and experiments should be done for comparison. the ml-modelling also is fully dependent on the result of the vader itself.
